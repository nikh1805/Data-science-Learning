# %%
import seaborn as sns

# %% [markdown]
# #### Features
# * f1 -> univariate analysis
# * f1, f2 -> Bivariate analysis
# * for more feature analysis we need belows as

# %% [markdown]
# #### Distribution plots
# * distplot
# * jointplot
# * pairplot  ## For more than one features as 4 , 5

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ### tip -> dependent feature
# ### total_bill, sex, smoker,day, time, size -> Independent features

# %% [markdown]
# ### Correlation with heatmap

# %% [markdown]
# ### A correlation heatmap  uses colored cells, typically in monocromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions or event types.

# %% [markdown]
# ### Interrelation between feature - only be find on interger or float values
# ### values will be ranging from -1 to +1 (pearson coff correlation)

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Join plot

# %% [markdown]
# ### A join plot allows to study the relationship between 2 numeric variables
# ### It is usually a scatterplot, a hexabin, a 2D histogram or a 2D debsity plot

# %%
sns.jointplot(x='tip', y='total_bill', data=df, kind='hex')

# %%
sns.jointplot(x='tip', y='total_bill', data=df, kind='reg') # Regression

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# ### Distplot

# %%
sns.distplot(df['tip'])
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'], kde=False, bins=10)
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### Categorical Plots
# * boxplot
# * violinplot
# * countplot
# * bar plot

# %%
sns.countplot('sex', data=df)
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(y='day', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(y='total_bill', x='sex', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Box plot

# %%
sns.boxplot('sex', 'total_bill', data=df)
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot('day', 'total_bill', data=df, palette='rainbow')
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df, orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df, x='total_bill', y='day', hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x='total_bill', y='day', data=df, pallete='rainbow')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
idf = sns.load_dataset('iris')
idf.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
idf.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
idf.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
idf.plot(kind='box', subplots=True, layout=(2,3), sharex=False, sharey=False, colormap='bwr', figsize=(15,10))
# Out:
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# C:\Users\NIKHIL HIRAGOND\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# sepal_length       AxesSubplot(0.125,0.536818;0.227941x0.343182)
# sepal_width     AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# petal_length    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# petal_width           AxesSubplot(0.125,0.125;0.227941x0.343182)
# dtype: object
